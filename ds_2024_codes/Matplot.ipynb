# %%
import matplotlib.pyplot as plt 
import numpy as np
x = np.array ([5, 7,8,7,2,17,2,9,4,11,
12,9, 6])
y = np.array ([99,86,87, 88, 111,86,103,
87,94, 78,77, 85,861])
plt. scatter (x, y)
x = np.array ([2, 2,8,1,15,8,12,9,7,3,
11,4, 7,14,12])
y = np.array ([100,105,84,105,90,99, 90,95,94,100,79,112,91, 80,851])
plt.scatter (x, y)
plt.show()

# %%
#for bar chart
plt.bar(x,y)
# Out:
# <BarContainer object of 15 artists>

# %%
#for hrotizontal bar chart
plt.barh(x,y)
# Out:
# <BarContainer object of 15 artists>

# %%
#historgram
plt.hist(x)
# Out:
# (array([3., 1., 1., 0., 2., 3., 0., 3., 0., 2.]),
#  array([ 1. ,  2.4,  3.8,  5.2,  6.6,  8. ,  9.4, 10.8, 12.2, 13.6, 15. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels=mylabels, startangle=90)
plt.show()
